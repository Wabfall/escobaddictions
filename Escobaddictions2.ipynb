# %% [markdown]
# # PROJET - ESCOBADDICTIONS
# ## 8PRO408 – Outils de programmation pour la science des données
# ### Auteurs : Andonin COUSSEAU / Etienne CHEVROLLIER / Khassan TASSOUEV / Damien BALLET

# %% [markdown]
# ## Etude 2 - L'utilisation des drogues par tranche d'âge
#
# [Lien Kaggle](https://www.kaggle.com/datasets/tunguz/drug-use-by-age)

# %% [markdown]
# Pourcentage de personnes d'un groupe d'âge ayant consommé la drogue au cours des 12 derniers mois
# Nombre médian de fois qu'un consommateur d'un groupe d'âge a consommé la drogue au cours des 12 derniers mois

# %%
import pandas as pd

# Chargement du fichier CSV Kaggle dans un DataFrame
df = pd.read_csv(".\\data\\drug-use-by-age.csv")
display(df)
# Out:
#       age     n  alcohol-use  alcohol-frequency  marijuana-use  \
# 0      12  2798          3.9                3.0            1.1
# 1      13  2757          8.5                6.0            3.4
# 2      14  2792         18.1                5.0            8.7
# 3      15  2956         29.2                6.0           14.5
# 4      16  3058         40.1               10.0           22.5
# 5      17  3038         49.3               13.0           28.0
# 6      18  2469         58.7               24.0           33.7
# 7      19  2223         64.6               36.0           33.4
# 8      20  2271         69.7               48.0           34.0
# 9      21  2354         83.2               52.0           33.0
# 10  22-23  4707         84.2               52.0           28.4
# 11  24-25  4591         83.1               52.0           24.9
# 12  26-29  2628         80.7               52.0           20.8
# 13  30-34  2864         77.5               52.0           16.4
# ...

# %% [markdown]
# #

# %%
df.columns= ['age','nombre_de_personnes', 'pourcentage_alcool', 'mediane_consommation_alcool', 'pourcentage_marijuana', 'mediane_consommation_marijuana','pourcentage_cocaine', 'mediane_consommation_cocaine', 'pourcentage_crack', 'mediane_consommation_crack', 'pourcentage_heroine', 'mediane_consommation_heroine', 'pourcentage_hallucinogene', 'mediane_consommation_hallucinogene', 'pourcentage_inhalation ', 'mediane_consommation_inhalation', 'pourcentage_antalgique', 'mediane_consommation_antalgique', 'pourcentage_oxycodone', 'mediane_consommation_oxycodone', 'pourcentage_tranquilisant', 'mediane_consommation_tranquilisant', 'pourcentage_stimulant', 'mediane_consommation_stimulant', 'pourcentage_meth', 'mediane_consommation_meth', 'pourcentage_sedatif', 'mediane_consommation_sedatif',]

display(df)
# Out:
#       age  nombre_de_personnes  pourcentage_alcool  \
# 0      12                 2798                 3.9
# 1      13                 2757                 8.5
# 2      14                 2792                18.1
# 3      15                 2956                29.2
# 4      16                 3058                40.1
# 5      17                 3038                49.3
# 6      18                 2469                58.7
# 7      19                 2223                64.6
# 8      20                 2271                69.7
# 9      21                 2354                83.2
# 10  22-23                 4707                84.2
# 11  24-25                 4591                83.1
# 12  26-29                 2628                80.7
# 13  30-34                 2864                77.5
# 14  35-49                 7391                75.0
# 15  50-64                 3923                67.2
# 16    65+                 2448                49.3
#
# ...

# %% [markdown]
# Exportation du DataFrame

# %%
# Exporter le dataframe en json
df.to_csv('.\\df_drogue_par_age.csv',decimal =',')

# test
